# %% [markdown]
# ## Content-Based Filtering Using Neural Networks

# %% [markdown]
# This lab relies on files created in the [content_based_preproc.ipynb](./content_based_preproc.ipynb) notebook. Be sure to complete the TODOs in that notebook and run the code there before completing this lab.
# Also, we'll be using the **python3** kernel from here on out so don't forget to change the kernel if it's still python2.

# %% [markdown]
# This lab illustrates:
# 1. how to build feature columns for a model using tf.feature_column
# 2. how to create custom evaluation metrics and add them to Tensorboard
# 3. how to train a model and make predictions with the saved model

# %% [markdown]
# Tensorflow Hub should already be installed. You can check using pip freeze.

# %%
# %bash
pip freeze | grep tensor
# Out:
# tensorboard==1.8.0
# tensorflow==1.8.0

# %% [markdown]
# If 'tensorflow-hub' isn't one of the outputs above, then you'll need to install it. Uncomment the cell below and execute the commands. After doing the pip install, click **"Reset Session"** on the notebook so that the Python environment picks up the new packages.

# %%
# %bash
pip install tensorflow-hub
# Out:
# Collecting tensorflow-hub
#   Using cached https://files.pythonhosted.org/packages/5a/76/18c9aaf24f1b888bafa40351493815050e100098b4782d634b307fb1ebc8/tensorflow_hub-0.2.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow-hub) (1.10.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow-hub) (1.14.0)
# Requirement already satisfied: protobuf>=3.4.0 in /usr/local/envs/py3env/lib/python3.5/site-packages (from tensorflow-hub) (3.6.1)
# Requirement already satisfied: setuptools in /usr/local/envs/py3env/lib/python3.5/site-packages (from protobuf>=3.4.0->tensorflow-hub) (40.2.0)
# Installing collected packages: tensorflow-hub
# Successfully installed tensorflow-hub-0.2.0

# %%
import os
import tensorflow as tf
import numpy as np
import tensorflow_hub as hub
import shutil

PROJECT = 'qwiklabs-gcp-5a88263a558147b5' # REPLACE WITH YOUR PROJECT ID
BUCKET = 'cloud-training-demos-ml' # REPLACE WITH YOUR BUCKET NAME
REGION = 'northamerica-northeast1-a' # REPLACE WITH YOUR BUCKET REGION e.g. us-central1

# do not change these
os.environ['PROJECT'] = PROJECT
os.environ['BUCKET'] = BUCKET
os.environ['REGION'] = REGION
os.environ['TFVERSION'] = '1.8'

# %%
# %bash
gcloud config set project $PROJECT
gcloud config set compute/region $REGION
# Out:
# Updated property [core/project].
# Updated property [compute/region].

# %% [markdown]
# ### Build the feature columns for the model.

# %% [markdown]
# To start, we'll load the list of categories, authors and article ids we created in the previous **Create Datasets** notebook.

# %%
categories_list = open("categories.txt").read().splitlines()
authors_list = open("authors.txt").read().splitlines()
content_ids_list = open("content_ids.txt").read().splitlines()
mean_months_since_epoch = 523

# %% [markdown]
# In the cell below we'll define the feature columns to use in our model. If necessary, remind yourself the [various feature columns](https://www.tensorflow.org/api_docs/python/tf/feature_column) to use.
# For the embedded_title_column feature column, use a Tensorflow Hub Module to create an embedding of the article title. Since the articles and titles are in German, you'll want to use a German language embedding module.
# Explore the text embedding Tensorflow Hub modules [available here](https://alpha.tfhub.dev/). Filter by setting the language to 'German'. The 50 dimensional embedding should be sufficient for our purposes.

# %%
embedded_title_column = hub.text_embedding_column("title", "https://tfhub.dev/google/nnlm-de-dim50/1", False)
#TODO: use a Tensorflow Hub module to create a text embeddding column for the article "title". 
                        # Use the module available at https://alpha.tfhub.dev/ filtering by German language.
  
categorical_content_column = tf.feature_column.categorical_column_with_hash_bucket(
        key = "content_id",
        hash_bucket_size = len(content_ids_list))    
embedded_content_column = tf.feature_column.embedding_column(
    categorical_column=categorical_content_column,
    dimension=10)
#TODO: create an embedded categorical feature column for the article id; i.e. "content_id".

categorical_author_column = tf.feature_column.categorical_column_with_hash_bucket(
        key = "author",
        hash_bucket_size = len(authors_list)) 
embedded_author_column = tf.feature_column.embedding_column(
    categorical_column=categorical_author_column,
    dimension=3)
#TODO: create an embedded categorical feature column for the article "author"

categorical_category_column = tf.feature_column.categorical_column_with_vocabulary_list(
        key="category",
        vocabulary_list=categories_list)
category_column = tf.feature_column.indicator_column(categorical_category_column)
#TODO: create a categorical feature column for the article "category"

months_since_epoch_boundaries = list(range(400,700,20))
numeric_months_since_epoch_column = tf.feature_column.numeric_column("months_since_epoch")
months_since_epoch_bucketized = tf.feature_column.bucketized_column(
    source_column = numeric_months_since_epoch_column,
    boundaries = months_since_epoch_boundaries)
#TODO: create a bucketized numeric feature column of values for the "months since epoch"

crossed_months_since_category_column = tf.feature_column.indicator_column(tf.feature_column.crossed_column(
    keys=[categorical_category_column, months_since_epoch_bucketized],
    hash_bucket_size=len(categories_list)*(len(months_since_epoch_boundaries)+1)))
#TODO: create a crossed feature column using the "category" and "months since epoch" values

feature_columns = [embedded_content_column,
                   embedded_author_column,
                   category_column,
                   embedded_title_column,
                   crossed_months_since_category_column]

# %% [markdown]
# ### Create the input function.
#
# Next we'll create the input function for our model. This input function reads the data from the csv files we created in the previous labs.

# %%
record_defaults = [["Unknown"], ["Unknown"],["Unknown"],["Unknown"],["Unknown"],[mean_months_since_epoch],["Unknown"]]
column_keys = ["visitor_id", "content_id", "category", "title", "author", "months_since_epoch", "next_content_id"]
label_key = "next_content_id"
def read_dataset(filename, mode, batch_size = 512):
  def _input_fn():
      def decode_csv(value_column):
          columns = tf.decode_csv(value_column,record_defaults=record_defaults)
          features = dict(zip(column_keys, columns))          
          label = features.pop(label_key)         
          return features, label

      # Create list of files that match pattern
      file_list = tf.gfile.Glob(filename)

      # Create dataset from file list
      dataset = tf.data.TextLineDataset(file_list).map(decode_csv)

      if mode == tf.estimator.ModeKeys.TRAIN:
          num_epochs = None # indefinitely
          dataset = dataset.shuffle(buffer_size = 10 * batch_size)
      else:
          num_epochs = 1 # end-of-input after this

      dataset = dataset.repeat(num_epochs).batch(batch_size)
      return dataset.make_one_shot_iterator().get_next()
  return _input_fn

# %% [markdown]
# ### Create the model and train/evaluate
#
#
# Next, we'll build our model which recommends an article for a visitor to the Kurier.at website. Look through the code below. We use the input_layer feature column to create the dense input layer to our network. This is just a sigle layer network where we can adjust the number of hidden units as a parameter.
#
# Currently, we compute the accuracy between our predicted 'next article' and the actual 'next article' read next by the visitor. Resolve the TODOs in the cell below by adding additional performance metrics to assess our model. You will need to
# * use the [tf.metrics library](https://www.tensorflow.org/api_docs/python/tf/metrics) to compute an additional performance metric
# * add this additional metric to the metrics dictionary, and
# * include it in the tf.summary that is sent to Tensorboard.

# %%
def model_fn(features, labels, mode, params):
  net = tf.feature_column.input_layer(features, params['feature_columns'])
  for units in params['hidden_units']:
        net = tf.layers.dense(net, units=units, activation=tf.nn.relu)
   # Compute logits (1 per class).
  logits = tf.layers.dense(net, params['n_classes'], activation=None) 

  predicted_classes = tf.argmax(logits, 1)
  from tensorflow.python.lib.io import file_io
    
  with file_io.FileIO('content_ids.txt', mode='r') as ifp:
    content = tf.constant([x.rstrip() for x in ifp])
  predicted_class_names = tf.gather(content, predicted_classes)
  if mode == tf.estimator.ModeKeys.PREDICT:
    predictions = {
        'class_ids': predicted_classes[:, tf.newaxis],
        'class_names' : predicted_class_names[:, tf.newaxis],
        'probabilities': tf.nn.softmax(logits),
        'logits': logits,
    }
    return tf.estimator.EstimatorSpec(mode, predictions=predictions)
  table = tf.contrib.lookup.index_table_from_file(vocabulary_file="content_ids.txt")
  labels = table.lookup(labels)
  # Compute loss.
  loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)

  # Compute evaluation metrics.
  accuracy = tf.metrics.accuracy(labels=labels,
                                 predictions=predicted_classes,
                                 name='acc_op')
  top_10_accuracy = tf.metrics.mean(tf.nn.in_top_k(logits,labels,10))
  #TODO: Compute the top_10 accuracy, using the tf.nn.in_top_k and tf.metrics.mean functions in Tensorflow
  
  metrics = {
    'accuracy': accuracy,
    'top_10_accuracy': top_10_accuracy
    #TODO: Add top_10_accuracy to the metrics dictionary
  }
  
  tf.summary.scalar('accuracy', accuracy[1])
  tf.summary.scalar('top_10_accuracy', top_10_accuracy[1])
  #TODO: Add the top_10_accuracy metric to the Tensorboard summary

  if mode == tf.estimator.ModeKeys.EVAL:
      return tf.estimator.EstimatorSpec(
          mode, loss=loss, eval_metric_ops=metrics)

  # Create training op.
  assert mode == tf.estimator.ModeKeys.TRAIN

  optimizer = tf.train.AdagradOptimizer(learning_rate=0.1)
  train_op = optimizer.minimize(loss, global_step=tf.train.get_global_step())
  return tf.estimator.EstimatorSpec(mode, loss=loss, train_op=train_op)

# %% [markdown]
# ### Train and Evaluate

# %%
outdir = 'content_based_model_trained'
shutil.rmtree(outdir, ignore_errors = True)
estimator = tf.estimator.Estimator(
    model_fn=model_fn,
    model_dir = outdir,
    params={
     'feature_columns': feature_columns,
      'hidden_units': [200, 100, 50],
      'n_classes': len(content_ids_list)
    })

train_spec = tf.estimator.TrainSpec(
    input_fn = read_dataset("training_set.csv", tf.estimator.ModeKeys.TRAIN),
    max_steps = 2000)

eval_spec = tf.estimator.EvalSpec(
    input_fn = read_dataset("test_set.csv", tf.estimator.ModeKeys.EVAL),
    steps = None,
    start_delay_secs = 30,
    throttle_secs = 60)

tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_evaluation_master': '', '_save_checkpoints_secs': 600, '_keep_checkpoint_every_n_hours': 10000, '_task_type': 'worker', '_session_config': None, '_num_worker_replicas': 1, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f45f4842198>, '_log_step_count_steps': 100, '_service': None, '_is_chief': True, '_train_distribute': None, '_tf_random_seed': None, '_task_id': 0, '_master': '', '_global_id_in_cluster': 0, '_model_dir': 'content_based_model_trained', '_save_checkpoints_steps': None, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 60 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 1, loss = 9.6589775
# INFO:tensorflow:global_step/sec: 2.01195
# INFO:tensorflow:step = 101, loss = 5.4811964 (49.710 sec)
# INFO:tensorflow:Saving checkpoints for 111 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.356476.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:13:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-111
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:14:07
# INFO:tensorflow:Saving dict for global step 111: accuracy = 0.015781866, global_step = 111, loss = 5.4134045, top_10_accuracy = 0.20606273
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-111
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 112 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 112, loss = 5.3017135
# INFO:tensorflow:global_step/sec: 1.98052
# INFO:tensorflow:step = 212, loss = 5.3066754 (50.499 sec)
# INFO:tensorflow:Saving checkpoints for 222 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.1986933.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:15:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-222
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:15:31
# INFO:tensorflow:Saving dict for global step 222: accuracy = 0.031680927, global_step = 222, loss = 5.2476115, top_10_accuracy = 0.23696238
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-222
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 223 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 223, loss = 5.1193976
# INFO:tensorflow:global_step/sec: 1.95746
# INFO:tensorflow:step = 323, loss = 5.119584 (51.094 sec)
# INFO:tensorflow:Saving checkpoints for 332 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.0547447.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:16:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-332
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:16:54
# INFO:tensorflow:Saving dict for global step 332: accuracy = 0.038282745, global_step = 332, loss = 5.1995244, top_10_accuracy = 0.2454002
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-332
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 333 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 333, loss = 5.183154
# INFO:tensorflow:global_step/sec: 1.98169
# INFO:tensorflow:step = 433, loss = 5.1475677 (50.469 sec)
# INFO:tensorflow:Saving checkpoints for 444 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.0748315.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:17:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-444
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:18:17
# INFO:tensorflow:Saving dict for global step 444: accuracy = 0.04054846, global_step = 444, loss = 5.168583, top_10_accuracy = 0.25313488
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-444
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 445 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 445, loss = 5.0540524
# INFO:tensorflow:global_step/sec: 1.99986
# INFO:tensorflow:step = 545, loss = 4.9481 (50.009 sec)
# INFO:tensorflow:Saving checkpoints for 555 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.0779815.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:19:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-555
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:19:39
# INFO:tensorflow:Saving dict for global step 555: accuracy = 0.040314075, global_step = 555, loss = 5.1300354, top_10_accuracy = 0.2586429
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-555
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 556 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 556, loss = 5.0232797
# INFO:tensorflow:global_step/sec: 1.99879
# INFO:tensorflow:step = 656, loss = 5.092762 (50.037 sec)
# INFO:tensorflow:Saving checkpoints for 667 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.0831265.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:20:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-667
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:21:02
# INFO:tensorflow:Saving dict for global step 667: accuracy = 0.04222821, global_step = 667, loss = 5.106447, top_10_accuracy = 0.27001056
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-667
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 668 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 668, loss = 5.035507
# INFO:tensorflow:global_step/sec: 1.98529
# INFO:tensorflow:step = 768, loss = 5.039197 (50.379 sec)
# INFO:tensorflow:Saving checkpoints for 775 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.991306.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:22:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-775
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:22:24
# INFO:tensorflow:Saving dict for global step 775: accuracy = 0.042657916, global_step = 775, loss = 5.0838323, top_10_accuracy = 0.27747178
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-775
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 776 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 776, loss = 5.001177
# INFO:tensorflow:global_step/sec: 1.99223
# INFO:tensorflow:step = 876, loss = 5.1205397 (50.203 sec)
# INFO:tensorflow:Saving checkpoints for 887 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.8102884.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:23:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-887
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:23:48
# INFO:tensorflow:Saving dict for global step 887: accuracy = 0.042814173, global_step = 887, loss = 5.0654693, top_10_accuracy = 0.27876088
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-887
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 888 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 888, loss = 4.832424
# INFO:tensorflow:global_step/sec: 2
# INFO:tensorflow:step = 988, loss = 4.874851 (50.006 sec)
# INFO:tensorflow:Saving checkpoints for 998 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.8297358.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:24:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-998
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:25:10
# INFO:tensorflow:Saving dict for global step 998: accuracy = 0.046173677, global_step = 998, loss = 5.035726, top_10_accuracy = 0.29126137
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-998
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 999 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 999, loss = 4.887519
# INFO:tensorflow:global_step/sec: 2.03231
# INFO:tensorflow:step = 1099, loss = 4.8615274 (49.211 sec)
# INFO:tensorflow:Saving checkpoints for 1112 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.8542476.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:26:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1112
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:26:34
# INFO:tensorflow:Saving dict for global step 1112: accuracy = 0.04793156, global_step = 1112, loss = 5.0154195, top_10_accuracy = 0.2965741
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1112
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1113 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 1113, loss = 4.8815026
# INFO:tensorflow:global_step/sec: 2.03608
# INFO:tensorflow:step = 1213, loss = 4.811221 (49.120 sec)
# INFO:tensorflow:Saving checkpoints for 1225 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.9633083.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:27:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1225
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:27:56
# INFO:tensorflow:Saving dict for global step 1225: accuracy = 0.04965038, global_step = 1225, loss = 4.994808, top_10_accuracy = 0.29993358
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1225
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1226 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 1226, loss = 4.8248634
# INFO:tensorflow:global_step/sec: 2.03334
# INFO:tensorflow:step = 1326, loss = 4.861292 (49.186 sec)
# INFO:tensorflow:Saving checkpoints for 1339 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.997137.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:29:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1339
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:29:20
# INFO:tensorflow:Saving dict for global step 1339: accuracy = 0.049064416, global_step = 1339, loss = 4.982124, top_10_accuracy = 0.3006758
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1339
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1340 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 1340, loss = 4.9109774
# INFO:tensorflow:global_step/sec: 2.03127
# INFO:tensorflow:step = 1440, loss = 4.9250107 (49.236 sec)
# INFO:tensorflow:Saving checkpoints for 1453 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.8559556.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:30:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1453
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:30:43
# INFO:tensorflow:Saving dict for global step 1453: accuracy = 0.051837962, global_step = 1453, loss = 4.9724126, top_10_accuracy = 0.3048166
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1453
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1454 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 1454, loss = 4.842419
# INFO:tensorflow:global_step/sec: 1.99683
# INFO:tensorflow:step = 1554, loss = 4.718829 (50.086 sec)
# INFO:tensorflow:Saving checkpoints for 1565 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.878479.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:31:47
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1565
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:32:05
# INFO:tensorflow:Saving dict for global step 1565: accuracy = 0.050900426, global_step = 1565, loss = 4.959148, top_10_accuracy = 0.30700418
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1565
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1566 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 1566, loss = 4.855084
# INFO:tensorflow:global_step/sec: 1.98873
# INFO:tensorflow:step = 1666, loss = 5.0394993 (50.291 sec)
# INFO:tensorflow:Saving checkpoints for 1676 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.880798.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:33:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1676
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:33:27
# INFO:tensorflow:Saving dict for global step 1676: accuracy = 0.053244267, global_step = 1676, loss = 4.9486713, top_10_accuracy = 0.30997303
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1676
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1677 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 1677, loss = 4.79449
# INFO:tensorflow:global_step/sec: 1.99986
# INFO:tensorflow:step = 1777, loss = 4.689002 (50.011 sec)
# INFO:tensorflow:Saving checkpoints for 1787 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.814311.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:34:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1787
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:34:50
# INFO:tensorflow:Saving dict for global step 1787: accuracy = 0.053908356, global_step = 1787, loss = 4.9337993, top_10_accuracy = 0.31575453
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1787
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1788 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 1788, loss = 4.789047
# INFO:tensorflow:global_step/sec: 1.98921
# INFO:tensorflow:step = 1888, loss = 4.762938 (50.278 sec)
# INFO:tensorflow:Saving checkpoints for 1898 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.7544394.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:35:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1898
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:36:12
# INFO:tensorflow:Saving dict for global step 1898: accuracy = 0.056447517, global_step = 1898, loss = 4.9267044, top_10_accuracy = 0.3191531
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-1898
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1899 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:step = 1899, loss = 4.752099
# INFO:tensorflow:global_step/sec: 1.96958
# INFO:tensorflow:step = 1999, loss = 4.8648796 (50.780 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into content_based_model_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.743245.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-02-19-20:37:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-02-19-20:37:31
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.055275597, global_step = 2000, loss = 4.9135118, top_10_accuracy = 0.32450485

# %% [markdown]
# ### Make predictions with the trained model.
#
# With the model now trained, we can make predictions by calling the predict method on the estimator. Let's look at how our model predicts on the first five examples of the training set.
# To start, we'll create a new file 'first_5.csv' which contains the first five elements of our training set. We'll also save the target values to a file 'first_5_content_ids' so we can compare our results.

# %%
# %%bash
# head -5 training_set.csv > first_5.csv
# head first_5.csv
# awk -F "\"*,\"*" '{print $2}' first_5.csv > first_5_content_ids
# Out:
# 1000148716229112932,299913368,News,U4-Störung legt Wiener Frühverkehr lahm ,Yvonne Widler,574,299931241
# 1000148716229112932,299931241,Stars & Kultur,Regisseur Michael Haneke kritisiert Flüchtlingspolitik,,574,299913879
# 1000360453832106474,299925700,Lifestyle,Nach Tod von Vater: Tochter bekommt jedes Jahr Blumen,Marlene Patsalidis,574,299922662
# 1000360453832106474,299922662,Lifestyle,Australischer Fernsehstar rechtfertigt Sexismus mit Asperger-Syndrom,Marlene Patsalidis,574,299826775
# 1001846185946874596,299930679,News,Wintereinbruch naht: Erster Schnee im Osten möglich,Daniela Wahl,574,299930679

# %% [markdown]
# Recall, to make predictions on the trained model we pass a list of examples through the input function. Complete the code below to make predicitons on the examples contained in the "first_5.csv" file we created above.

# %%
output = list(estimator.predict(
  input_fn = read_dataset("first_5.csv", tf.estimator.ModeKeys.PREDICT)
))
#TODO: Use the predict method on our trained model to find the predictions for the examples contained in "first_5.csv".
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Initialize variable input_layer/title_hub_module_embedding/module/embeddings/part_0:0 from checkpoint b'/tmp/tfhub_modules/e40ef097142ae1de637df7021ce148ffe836e262/variables/variables' with embeddings
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from content_based_model_trained/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
import numpy as np
recommended_content_ids = [np.asscalar(d["class_names"]).decode('UTF-8') for d in output]
content_ids = open("first_5_content_ids").read().splitlines()

# %% [markdown]
# Finally, we'll map the content id back to the article title. We can then compare our model's recommendation for the first of our examples. This can all be done in BigQuery. Look through the query below and make sure it is clear what is being returned.

# %%
import google.datalab.bigquery as bq
recommended_title_sql="""
#standardSQL
SELECT
(SELECT MAX(IF(index=6, value, NULL)) FROM UNNEST(hits.customDimensions)) AS title
FROM `cloud-training-demos.GA360_test.ga_sessions_sample`,   
  UNNEST(hits) AS hits
WHERE 
  # only include hits on pages
  hits.type = "PAGE"
  AND (SELECT MAX(IF(index=10, value, NULL)) FROM UNNEST(hits.customDimensions)) = \"{}\"
LIMIT 1""".format(recommended_content_ids[0])

current_title_sql="""
#standardSQL
SELECT
(SELECT MAX(IF(index=6, value, NULL)) FROM UNNEST(hits.customDimensions)) AS title
FROM `cloud-training-demos.GA360_test.ga_sessions_sample`,   
  UNNEST(hits) AS hits
WHERE 
  # only include hits on pages
  hits.type = "PAGE"
  AND (SELECT MAX(IF(index=10, value, NULL)) FROM UNNEST(hits.customDimensions)) = \"{}\"
LIMIT 1""".format(content_ids[0])
recommended_title = bq.Query(recommended_title_sql).execute().result().to_dataframe()['title'].tolist()[0]
current_title = bq.Query(current_title_sql).execute().result().to_dataframe()['title'].tolist()[0]
print("Current title: {} ".format(current_title))
print("Recommended title: {}".format(recommended_title))
# Out:
# Current title: U4-Störung legt Wiener Frühverkehr lahm
# Recommended title: Fahnenskandal von Mailand: Die Austria zeigt Flagge

# %% [markdown]
# ### Tensorboard
#
# As usual, we can monitor the performance of our training job using Tensorboard.

# %%
from google.datalab.ml import TensorBoard
TensorBoard().start('content_based_model_trained')
# Out:
# <p>TensorBoard was started successfully with pid 5320. Click <a href="/_proxy/58039/" target="_blank">here</a> to access it.</p>
# 5320

# %%
for pid in TensorBoard.list()['pid']:
  TensorBoard().stop(pid)
  print("Stopped TensorBoard with pid {}".format(pid))
